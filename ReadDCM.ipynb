# %% [markdown]
# # To read and View DICOM files

# %% [markdown]
# Importing the required libraries

# %%
import pydicom
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
InputFolder='TCGA-THCA/' #Input Directory containing dicom images of patients
InputPath=os.listdir(InputFolder)

# %%
filesDCM=[] #Stores name of all dcm files
Error=[]    #Stores name of files that produce error while handling pixel data

for dirName,subdirList,fileList in os.walk(InputFolder):
    for fileName in fileList:
        if ".dcm" in fileName.lower():
            ds=pydicom.read_file(os.path.join(dirName,fileName))
            try:
                ds.pixel_array
                filesDCM.append(os.path.join(dirName,fileName))
            except:
                Error.append(os.path.join(dirName,fileName))

# %%
print(len(Error), "files produced error.")
print(Error)
# Out:
# 5 files produced error.
# ['TCGA-THCA/TCGA-DE-A4MA\\06-13-2004-PETCT Tumor Img. Skull Base to Mid-thigh-17769\\3-CTSkullToThigh  5.0  B30f-35056\\000000.dcm', 'TCGA-THCA/TCGA-DE-A4MA\\06-13-2004-PETCT Tumor Img. Skull Base to Mid-thigh-17769\\4-CT HeadNeck  3.0  eFoV-85383\\000098.dcm', 'TCGA-THCA/TCGA-DE-A4MA\\06-13-2004-PETCT Tumor Img. Skull Base to Mid-thigh-17769\\4-CTSkullToThigh  5.0  eFoV-70599\\000001.dcm', 'TCGA-THCA/TCGA-DE-A4MB\\07-05-2004-Outside Read or Comparison NEURO CT-12859\\2-ISO370 100ML-99801\\000046.dcm', 'TCGA-THCA/TCGA-DE-A4MC\\07-21-2004-CT NECK SOFT TISSUE  W CONTR-24988\\6-Neck  ST Coronal-45654\\000045.dcm']

# %% [markdown]
# ### Viewing the information present in dicom file.

# %% [markdown]
# Viewing files according to list created according to index.

# %%
#Here just change the index to view information contained in different files.
len(filesDCM)
# Out:
# 1369

# %%
index=10
pydicom.read_file(filesDCM[index])
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20040527'
# (0008, 0013) Instance Creation Time              TM: '141232'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8421.4019.301009062513524088810000048828
# (0008, 0020) Study Date                          DA: '20040527'
# (0008, 0021) Series Date                         DA: '20040527'
# (0008, 0022) Acquisition Date                    DA: '20040527'
# (0008, 0023) Content Date                        DA: '20040527'
# (0008, 0030) Study Time                          TM: '140909.000000'
# (0008, 0031) Series Time                         TM: '140909'
# (0008, 0032) Acquisition Time                    TM: '141006'
# ...

# %% [markdown]
# Viewing the Information present in error file.

# %%
pydicom.read_file(Error[0])
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8421.4019.268531158448470480819062448914
# (0008, 0020) Study Date                          DA: '20040613'
# (0008, 0021) Series Date                         DA: '20040613'
# (0008, 0022) Acquisition Date                    DA: '20040613'
# (0008, 0023) Content Date                        DA: '20040613'
# (0008, 0030) Study Time                          TM: '125658.593000'
# (0008, 0031) Series Time                         TM: '130239.828000'
# (0008, 0032) Acquisition Time                    TM: '130202.278301'
# (0008, 0033) Content Time                        TM: '130202.278301'
# (0008, 0050) Accession Number                    SH: '1573833216616748'
# ...

# %% [markdown]
# Viewing the files according to the location

# %%
#Just change the location to view a different file.
location = "TCGA-THCA/TCGA-DE-A4MA/05-27-2004-Outside Read or Comparison NEURO CT-84907/10-SOFT TISSUE NECK 2.5MM-81987/000001.dcm"

# %%
pydicom.read_file(location)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20040527'
# (0008, 0013) Instance Creation Time              TM: '141046'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8421.4019.724357236551305355498795725009
# (0008, 0020) Study Date                          DA: '20040527'
# (0008, 0021) Series Date                         DA: '20040527'
# (0008, 0022) Acquisition Date                    DA: '20040527'
# (0008, 0023) Content Date                        DA: '20040527'
# (0008, 0030) Study Time                          TM: '140909.000000'
# (0008, 0031) Series Time                         TM: '140909'
# (0008, 0032) Acquisition Time                    TM: '141006'
# ...

# %% [markdown]
# Viewing the images stored in a DICOM file according to .dcm file location

# %%
ds =pydicom.read_file(location)
plt.set_cmap(plt.gray())
plt.imshow(ds.pixel_array)
